# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
from scipy.stats import sem
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_df = pd.merge(mouse_metadata, study_results, how="inner", on= 'Mouse ID')
# Display the data table for preview
merged_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
mouse_count = merged_df["Mouse ID"].count()
mouse_count
# Out:
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice = merged_df[merged_df.duplicated(['Mouse ID', 'Timepoint'])]
duplicate_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_rows = merged_df[merged_df.duplicated(['Mouse ID',])]
duplicate_rows
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# 5        k403     Ramicane  Male          21          16         25
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1              38.825898                 0
# 2              35.014271                 1
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = merged_df.drop_duplicates('Mouse ID')
clean_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 10       s185    Capomulin  Female           3          17          0
# 20       x401    Capomulin  Female          16          15          0
# 30       m601    Capomulin    Male          22          17          0
# 40       g791     Ramicane    Male          11          16          0
# ...       ...          ...     ...         ...         ...        ...
# 1858     z314     Stelasyn  Female          21          28          0
# 1860     z435     Propriva  Female          12          26          0
# 1863     z581    Infubinol  Female          24          25          0
# 1873     z795     Naftisol  Female          13          29          0
# 1883     z969     Naftisol    Male           9          30          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                   45.0                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
mouse_count_clean = clean_df['Mouse ID'].count()
mouse_count_clean
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

mean = merged_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
median = merged_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
variance = merged_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
standard_dev = merged_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
sem = merged_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()

summary_df = pd.DataFrame({"Mean": mean, 
                           "Median": median, 
                           "Variance": variance,
                          "Standard Deviation": standard_dev,
                          "SEM": sem})
summary_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070            6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line

aggregate_stats = merged_df.groupby('Drug Regimen').agg({'Tumor Volume (mm3)':['mean','median', 'var', 'std', 'sem']})
aggregate_stats
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.

mice_per_drug = merged_df.groupby(["Drug Regimen"]).count()["Mouse ID"]


pandas_plot = mice_per_drug.plot.bar(figsize=(10,5), color = 'yellowgreen', align = 'center', fontsize=11)
plt.xlabel("Drug Regimen", fontsize = 15)
plt.ylabel("Number of Mice", fontsize = 15)
plt.title("Figure 1.  Number of Mice Per Drug Regimen", fontsize = 18)
plt.tight_layout()
plt.savefig("Figures/Figure 1.Number of Mice Per Drug Regimen.png", bbox_inches = "tight")
plt.show()

df = pd.DataFrame(mice_per_drug)
df
# Out:
#               Mouse ID
# Drug Regimen
# Capomulin          230
# Ceftamin           178
# Infubinol          178
# Ketapril           188
# Naftisol           186
# Placebo            181
# Propriva           161
# Ramicane           228
# Stelasyn           181
# Zoniferol          182

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.
drug_list = summary_df.index.tolist()
drug_list
# Out:
# ['Capomulin',
#  'Ceftamin',
#  'Infubinol',
#  'Ketapril',
#  'Naftisol',
#  'Placebo',
#  'Propriva',
#  'Ramicane',
#  'Stelasyn',
#  'Zoniferol']

# %%
mice_count = (merged_df.groupby(["Drug Regimen"])["Mouse ID"].count()).tolist()
mice_count
# Out:
# [230, 178, 178, 188, 186, 181, 161, 228, 181, 182]

# %%
x_axis = np.arange(len(mice_count))
x_axis = drug_list

plt.figure(figsize=(10,5))
plt.bar(x_axis, mice_count, color='turquoise', alpha=0.5, align = "center")
plt.xlabel("Drug Regimen", fontsize=15)
plt.ylabel("Number of Mice", fontsize=15)
plt.title("Figure 2. Number of Mice Per Drug Regimen")
plt.tight_layout
plt.savefig("Figures/Figure 2.Number of Mice Per Drug Regimen.png", bbox_inches = "tight")

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_df = pd.DataFrame(merged_df.groupby(["Sex"]).count()).reset_index()
gender_df
# Out:
#       Sex  Mouse ID  Drug Regimen  Age_months  Weight (g)  Timepoint  \
# 0  Female       935           935         935         935        935
# 1    Male       958           958         958         958        958
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0                 935               935
# 1                 958               958

# %%
gender_df = gender_df[["Sex", "Mouse ID"]]
gender_df
# Out:
#       Sex  Mouse ID
# 0  Female       935
# 1    Male       958

# %%
plt.figure(figsize=(10,5))
ax1 = plt.subplot(121, aspect = "equal")

gender_df.plot(kind = "pie", 
              y = "Mouse ID", 
              ax = ax1, 
              autopct = '%1.1f%%',
             startangle = 90,
             shadow = True,
             labels = gender_df["Sex"],
             legend = False,
             fontsize = 12,
              colors = ['plum', 'purple'])

plt.xlabel('')
plt.ylabel('')
plt.title("Figure 3. Sex Distribution Among Mice Test Subjects")

plt.savefig("Figures/Figure 3.Sex Distribution Among Mice Test Subjects.png", bbox_inches = "tight")

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_count = (merged_df.groupby(["Sex"])["Mouse ID"].count()).tolist()
gender_count
# Out:
# [935, 958]

# %%
labels = ["Female", "Male"]
colors = ["magenta", "lime"]
explode = (0.05, 0)

plt.figure(figsize=(10,5))
plt.pie(gender_count, 
        explode = explode, 
        labels = labels, 
        colors = colors,
        autopct = '%1.1f%%',
        shadow = True, 
        startangle = 90)
plt.axis("equal")
plt.title("Figure 4. Sex Distribution Among Mice Test Subjects")
plt.savefig("Figures/Figure 4. Sex Distribution Among Mice Test Subjects.png", bbox="tight")

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

max_timepoint_df = pd.DataFrame(merged_df.groupby('Mouse ID')['Timepoint'].max().sort_values()).reset_index().rename(columns={'Timepoint': 'max_timepoint'})
max_timepoint_df
# Out:
#     Mouse ID  max_timepoint
# 0       t573              0
# 1       u153              0
# 2       d133              0
# 3       n482              0
# 4       o848              0
# ..       ...            ...
# 244     k894             45
# 245     l471             45
# 246     l509             45
# 247     i177             45
# 248     z969             45
#
# [249 rows x 2 columns]

# %%
data_df = pd.merge(merged_df, max_timepoint_df, on = 'Mouse ID')
data_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites  max_timepoint
# 0           45.000000                 0             45
# 1           38.825898                 0             45
# 2           35.014271                 1             45
# 3           34.223992                 1             45
# 4           32.997729                 1             45

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Create empty list to fill with tumor vol data (for plotting)
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # add subset 
    # Determine outliers using upper and lower bounds 
    
drugs = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
drug_list = []

for drug in drugs:
    
    df = data_df.loc[data_df['Drug Regimen'] == drug]    
    final_volume = df.loc[df['Timepoint'] == df['max_timepoint']]
    values = final_volume['Tumor Volume (mm3)']
    drug_list.append(values)
    
    quartiles = values.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    print(f'IQR for {drug}: {iqr}')
    
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f'Lower Bound for {drug}: {lower_bound}')
    print(f'Upper Bound for {drug}: {upper_bound}')
    
    outliers_count = (values.loc[(final_volume['Tumor Volume (mm3)'] >= upper_bound) | 
                                        (final_volume['Tumor Volume (mm3)'] <= lower_bound)]).count()
    print(f'Number of {drug} outliers: {outliers_count}')
# Out:
# IQR for Capomulin: 7.781863460000004
# Lower Bound for Capomulin: 20.70456164999999
# Upper Bound for Capomulin: 51.83201549
# Number of Capomulin outliers: 0
# IQR for Ramicane: 9.098536719999998
# Lower Bound for Ramicane: 17.912664470000003
# Upper Bound for Ramicane: 54.30681135
# Number of Ramicane outliers: 0
# IQR for Infubinol: 11.477135160000003
# Lower Bound for Infubinol: 36.83290494999999
# Upper Bound for Infubinol: 82.74144559000001
# Number of Infubinol outliers: 1
# IQR for Ceftamin: 15.577752179999997
# Lower Bound for Ceftamin: 25.355449580000002
# Upper Bound for Ceftamin: 87.66645829999999
# Number of Ceftamin outliers: 0

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
flierprops = dict(marker='D', markerfacecolor='b', markersize=8, markeredgecolor='azure')

plt.boxplot(drug_list, flierprops=flierprops)

plt.title("Figure 5. Final Tumor Volume")
plt.ylabel("Final Tumor Volume (mm3)")
plt.xlabel("Drug")
plt.xticks([1, 2, 3, 4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])

plt.show()
plt.savefig("Figures/Figure 5. Final Tumor Volume.png")

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

test_subject = merged_df.loc[merged_df['Mouse ID'] == 'x401']

plt.plot(test_subject['Timepoint'], test_subject['Tumor Volume (mm3)'], marker = 's', color = 'red')
plt.xlabel("Time (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Figure 6. Capomulin Treatment Results of Mouse x401")
plt.show()

plt.savefig("Figures/Figure 6. Capomulin Treatment Results of Mouse x401.png")

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

capomulin_df = merged_df.loc[merged_df['Drug Regimen'] == 'Capomulin']
avg_volume = pd.DataFrame(capomulin_df.groupby('Mouse ID')['Tumor Volume (mm3)'].mean().sort_values()).reset_index().rename(columns={'Tumor Volume (mm3)': 'Average Tumor Volume'})
avg_volume = pd.merge(capomulin_df, avg_volume, on='Mouse ID')
final_avg_vol_df = avg_volume[['Weight (g)', 'Average Tumor Volume']].drop_duplicates()
final_avg_vol_df
# Out:
#      Weight (g)  Average Tumor Volume
# 0            17             34.559143
# 10           15             36.182040
# 20           17             34.847470
# 30           17             36.505973
# 35           17             39.887495
# 45           17             38.506829
# 55           17             36.509212
# 65           19             39.049816
# 75           17             39.328725
# 85           20             39.141053
# 95           21             41.352452
# 105          19             41.990097
# 115          19             42.507261
# 125          21             40.083699
# 135          22             41.963636
# 145          21             43.216925
# 153          23             44.465236
# 163          23             41.384825
# 166          21             41.581595
# 176          22             44.613344
# 186          23             42.803733
# 196          21             44.434474
# 206          25             43.367364
# 216          24             44.805810
# ...

# %%
x = final_avg_vol_df['Weight (g)']
y = final_avg_vol_df['Average Tumor Volume']

fig1, ax1 = plt.subplots(figsize=(15,8))
plt.scatter(x, y)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Figure 7. Average Tumor Volume vs Test Subject Weight')
plt.show()

plt.savefig("Figures/Figure 7. Average Tumor Volume vs Test Subject Weight.png")

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

capomulin_df = merged_df.loc[merged_df['Drug Regimen'] == 'Capomulin']
avg_volume = pd.DataFrame(capomulin_df.groupby('Mouse ID')['Tumor Volume (mm3)'].mean().sort_values()).reset_index().rename(columns={'Tumor Volume (mm3)': 'Average Tumor Volume'})
avg_volume = pd.merge(capomulin_df, avg_volume, on='Mouse ID')
final_avg_vol_df = avg_volume[['Weight (g)', 'Average Tumor Volume']].drop_duplicates()
final_avg_vol_df.head()
x = final_avg_vol_df['Weight (g)']
y = final_avg_vol_df['Average Tumor Volume']


correlation = st.pearsonr(x,y)


print(f"""The correlation between weight and average tumor volume
on the Capomulin regimen is {round(correlation[0],2)}.""")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

fig1, ax1 = plt.subplots(figsize=(15,8))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")

plt.annotate(line_eq,(20,37),fontsize=15,color="red")

plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Figure 8. Average Tumor Volume by Weight (Linear Regression)')
plt.show()

plt.savefig("Figures/Figure 8. Average Tumor by Weight (Linear Regression).png")
# Out:
# The correlation between weight and average tumor volume
# on the Capomulin regimen is 0.84.

# %% [markdown]
# # ANALYSIS INSIGHTS

# %% [markdown]
# 1. With respect to reducing tumor sizes, Capomulin and Ramicane have comparable (or similar) results, but are both significantly more effective than Infubinol and Ceftamine.
#
# 2. There is a direct relationship between the weight of the test subject and tumor volume (greater weight = greater tumor volume). This can further imply that drug effectivity is reduced as the test subject's weight increases.
#
# 3. Test results for Capomulin, Ramicane, Infubinol and Ceftamin can be considere reliable, as there is only one outlying value (for Infubinol).
#
# 4. Results show that there is a fairly strong positive relationship between average tumor volume and weight (correlation coefficient = 0.84.
